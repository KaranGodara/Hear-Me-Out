# %%
import os

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# !pip install tensorboard
# Out:
# ...
#   Using cached tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# ...
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# ...
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# ...
#   Using cached absl_py-1.2.0-py3-none-any.whl (123 kB)
# ...
#      |████████████████████████████████| 3.5 MB 5.5 MB/s eta 0:00:01
# ...
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# ...
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# ...

# %%
# !cd yolov5 && python train.py --img 320 --batch 4 --epoch 500 --data dataset.yml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=500, batch_size=4, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 9 (delta 7), reused 8 (delta 7), pack-reused 0
# Unpacking objects: 100% (9/9), 1.12 KiB | 25.00 KiB/s, done.
# From https://github.com/ultralytics/yolov5
#    38721de..b17629e  master     -> origin/master
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path = 'yolov5/runs/train/exp2/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /Users/karangodara/.cache/torch/hub/master.zip
# YOLOv5 🚀 2022-7-25 Python-3.9.12 torch-1.12.0 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7061368 parameters, 0 gradients
# Adding AutoShape...

# %%
img = os.path.join('data','test','thumbsup.21591578-0a95-11ed-94b5-fa34836c0e44.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 720x1280 1 ThumbsUp
# Speed: 84.5ms pre-process, 1048.1ms inference, 19.0ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))

# %%
img = os.path.join('data','test','thumbsdown.28294184-0a95-11ed-94b5-fa34836c0e44.jpg')
results = model(img)
results.print()
plt.imshow(np.squeeze(results.render()))
# Out:
# image 1/1: 720x1280 1 ThumbsDown
# Speed: 57.9ms pre-process, 666.8ms inference, 1.1ms NMS per image at shape (1, 3, 384, 640)

# %%
img = os.path.join('data','test','thankyou.a0349d04-0a95-11ed-94b5-fa34836c0e44.jpg')
results = model(img)
results.print()
plt.imshow(np.squeeze(results.render()))
# Out:
# image 1/1: 720x1280 1 ThankYou
# Speed: 30.3ms pre-process, 503.3ms inference, 1.1ms NMS per image at shape (1, 3, 384, 640)

# %%
img = os.path.join('data','test','thankyou.a1768db2-0a95-11ed-94b5-fa34836c0e44.jpg')
results = model(img)
results.print()
plt.imshow(np.squeeze(results.render()))
# Out:
# image 1/1: 720x1280 1 ThankYou
# Speed: 67.7ms pre-process, 523.9ms inference, 0.9ms NMS per image at shape (1, 3, 384, 640)

# %%
img = os.path.join('data','images','livelong.6fc90d8a-0a95-11ed-94b5-fa34836c0e44.jpg')
results = model(img)
results.print()
plt.imshow(np.squeeze(results.render()))
# Out:
# image 1/1: 720x1280 1 LiveLong
# Speed: 31.0ms pre-process, 512.8ms inference, 2.4ms NMS per image at shape (1, 3, 384, 640)

# %%
img = os.path.join('data','images','livelong.aacad9ea-0a95-11ed-94b5-fa34836c0e44.jpg')
results = model(img)
results.print()
plt.imshow(np.squeeze(results.render()))
# Out:
# image 1/1: 720x1280 1 LiveLong
# Speed: 51.8ms pre-process, 492.5ms inference, 0.8ms NMS per image at shape (1, 3, 384, 640)

# %%
img = os.path.join('data','images','livelong.ac0b9466-0a95-11ed-94b5-fa34836c0e44.jpg')
results = model(img)
results.print()
plt.imshow(np.squeeze(results.render()))
# Out:
# image 1/1: 720x1280 1 LiveLong
# Speed: 29.0ms pre-process, 507.3ms inference, 0.9ms NMS per image at shape (1, 3, 384, 640)

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    #Make Detections
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render() ))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
